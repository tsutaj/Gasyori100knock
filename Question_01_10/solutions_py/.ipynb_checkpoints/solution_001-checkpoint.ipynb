# %%
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
img = cv2.imread("../imori.jpg")
img = img[:, :, (2, 1, 0)]

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)) # OpenCV は色が GBR 順なので RGB 順に並べ替える
plt.show()
